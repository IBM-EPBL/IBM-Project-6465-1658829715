# %% [markdown]
# ## **IBM Project: Real-Time Communication System Powered by AI for Specially Abled**

# %% [markdown]
# # TEAM ID: PNT2022TMID48155

# %% [markdown]
# # ***IMPORTING NECESSARY LIBRARIES***

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-d5df0069828e> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     104       timeout_ms=timeout_ms,
#     105       ephemeral=True,
# --> 106       readonly=readonly)
#     107
#     108
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     123   if ephemeral:
#     124     _message.blocking_request(
# --> 125         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     126
#     127   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator

# %%
# !unzip '/content/drive/MyDrive/test_set.zip'
# Out:
# Archive:  /content/drive/MyDrive/test_set.zip
#    creating: test_set/A/
#   inflating: test_set/A/1.png
#   inflating: test_set/A/10.png
#  extracting: test_set/A/100.png
#   inflating: test_set/A/101.png
#   inflating: test_set/A/102.png
#  extracting: test_set/A/103.png
#   inflating: test_set/A/104.png
#   inflating: test_set/A/105.png
#   inflating: test_set/A/106.png
#   inflating: test_set/A/107.png
#   inflating: test_set/A/108.png
#   inflating: test_set/A/109.png
#   inflating: test_set/A/11.png
#   inflating: test_set/A/110.png
#   inflating: test_set/A/111.png
#   inflating: test_set/A/112.png
#   inflating: test_set/A/113.png
#   inflating: test_set/A/114.png
#   inflating: test_set/A/115.png
#  extracting: test_set/A/116.png
#   inflating: test_set/A/117.png
#   inflating: test_set/A/118.png
#   inflating: test_set/A/119.png
#   inflating: test_set/A/12.png
#   inflating: test_set/A/120.png
#   inflating: test_set/A/121.png
#   inflating: test_set/A/122.png
# ...

# %%
 # !unzip '/content/drive/MyDrive/training_set.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: training_set/G/1225.png
#  extracting: training_set/G/1226.png
#  extracting: training_set/G/1227.png
#  extracting: training_set/G/1228.png
#  extracting: training_set/G/1229.png
#   inflating: training_set/G/123.png
#  extracting: training_set/G/1230.png
#  extracting: training_set/G/1231.png
#  extracting: training_set/G/1232.png
#   inflating: training_set/G/1233.png
#   inflating: training_set/G/1234.png
#   inflating: training_set/G/1235.png
#   inflating: training_set/G/1236.png
#   inflating: training_set/G/1237.png
#   inflating: training_set/G/1238.png
#   inflating: training_set/G/1239.png
#   inflating: training_set/G/124.png
#   inflating: training_set/G/1240.png
#   inflating: training_set/G/1241.png
#   inflating: training_set/G/1242.png
#   inflating: training_set/G/1243.png
#   inflating: training_set/G/1244.png
#   inflating: training_set/G/1245.png
#  extracting: training_set/G/1246.png
# ...

# %% [markdown]
# # **RENAMING DATA FILES**

# %%
def rename_imgs(file_name):
    folder_path = r'/content/drive/MyDrive/test_dataset'+file_name

    num = 0
    for file in os.listdir(folder_path):
        # if num%10 == 0:
        #     print(f'Renamed {num} files...')
        # os.rename(folder_path+'\\'+file, folder_path+'\\'+file_name+'_'+str(num)+'.jpeg')
        num += 1

# %%
fn = ''
rename_imgs(fn)

# %%
file_names = ''
for fn in file_names:
    rename_imgs(fn)

# %% [markdown]
# # **DISPLAYING SAMPLE IMAGES FROM DATASET**

# %%
train_data_path = '/content/training_set'
test_data_path = '/content/test_set'

# %%
def display(img,sign=None):
    
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    fig = plt.figure(figsize=(7,7))
    ax = fig.add_subplot(111)
    plt.title(sign)
    ax.imshow(img)

# %% [markdown]
# ## **Training Data Images**

# %%
sign_img = cv2.imread('/content/drive/MyDrive/train_dataset/3/23.jpg')
display(sign_img,'a')

# %%
sign_img = cv2.imread('/content/drive/MyDrive/test_dataset/A/244.jpg')
display(sign_img,'A')

# %%
sign_img = cv2.imread('/content/drive/MyDrive/test_dataset/D/7.jpg')
display(sign_img,'D')

# %%
sign_img = cv2.imread('/content/drive/MyDrive/train_dataset/3/340.jpg')
display(sign_img,'3')

# %%
sign_img = cv2.imread('/content/drive/MyDrive/test_dataset/H/7.jpg')
display(sign_img,'7')

# %%
sign_img = cv2.imread('/content/drive/MyDrive/test_dataset/Z/1.jpg')
display(sign_img,'Z')

# %%
sign_img = cv2.imread('/content/drive/MyDrive/test_dataset/P/8.jpg')
display(sign_img,'5')

# %% [markdown]
# # **Test Data Images**

# %%
sign_img = cv2.imread('/content/drive/MyDrive/test_dataset/S/15.jpg')
display(sign_img,'S')

# %%
sign_img = cv2.imread('/content/drive/MyDrive/test_dataset/Z/1.jpg')
display(sign_img,'Z')

# %%
sign_img = cv2.imread('/content/drive/MyDrive/test_dataset/7/8.jpg')
display(sign_img,'7')

# %% [markdown]
# # **AUGMENTATION AND PREPROCESSING THE DATASET**

# %% [markdown]
# **Creating ImageDataGenerator**

# %%
image_gen = ImageDataGenerator(rotation_range=30,
                              width_shift_range=0.1,
                              height_shift_range=0.1,
                              shear_range=0.2,
                              zoom_range=0.2,
                              rescale=1/255,
                              horizontal_flip=True,
                              fill_mode='nearest',
                              validation_split=0.25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4d45b026fa20> in <module>
# ----> 1 image_gen = ImageDataGenerator(rotation_range=30,
#       2                               width_shift_range=0.1,
#       3                               height_shift_range=0.1,
#       4                               shear_range=0.2,
#       5                               zoom_range=0.2,
#
# NameError: name 'ImageDataGenerator' is not defined

# %% [markdown]
# **Original Image**

# %%
sign_img = cv2.imread('/content/drive/MyDrive/test_dataset/3/100.jpg')
display(sign_img,'3')

# %% [markdown]
# **Augmented Images**

# %%
display(image_gen.random_transform(sign_img))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-117d2b61031e> in <module>
# ----> 1 display(image_gen.random_transform(sign_img))
#
# NameError: name 'image_gen' is not defined

# %%
display(image_gen.random_transform(sign_img))

# %% [markdown]
# # **SPLITING INTO TRAIN AND VALIDATION DATASET**

# %% [markdown]
# **Train Data Generator**

# %%
train_data_gen = image_gen.flow_from_directory('/content/drive/MyDrive/train_dataset',
                                           target_size=(250,250),
                                           batch_size=16,
                                           shuffle=True,
                                           class_mode='binary',
                                           subset='training')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3bcfa3745070> in <module>
# ----> 1 train_data_gen = image_gen.flow_from_directory('/content/drive/MyDrive/train_dataset',
#       2                                            target_size=(250,250),
#       3                                            batch_size=16,
#       4                                            shuffle=True,
#       5                                            class_mode='binary',
#
# NameError: name 'image_gen' is not defined

# %% [markdown]
# **Validation Data Generator**

# %%
validation_data_gen = image_gen.flow_from_directory('/content/test_set',
                                           target_size=(250,250),
                                           batch_size=16,
                                           shuffle=True,
                                           class_mode='binary',
                                           subset='validation')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-cfe942374631> in <module>
# ----> 1 validation_data_gen = image_gen.flow_from_directory('/content/test_set',
#       2                                            target_size=(250,250),
#       3                                            batch_size=16,
#       4                                            shuffle=True,
#       5                                            class_mode='binary',
#
# NameError: name 'image_gen' is not defined

# %% [markdown]
# **Test Data Generator**

# %%
test_data_gen = image_gen.flow_from_directory('/content/drive/MyDrive/test_dataset',
                                           target_size=(250,250),
                                           batch_size=8,
                                           shuffle=True,
                                           class_mode='categorical',
                                           )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a9f36d07ca52> in <module>
# ----> 1 test_data_gen = image_gen.flow_from_directory('/content/drive/MyDrive/test_dataset',
#       2                                            target_size=(250,250),
#       3                                            batch_size=8,
#       4                                            shuffle=True,
#       5                                            class_mode='categorical',
#
# NameError: name 'image_gen' is not defined

# %%
train_data_gen.class_indices
# Out:
# {'3': 0,
#  '4': 1,
#  '5': 2,
#  '6': 3,
#  '7': 4,
#  '8': 5,
#  '9': 6,
#  'A': 7,
#  'B': 8,
#  'C': 9,
#  'D': 10,
#  'E': 11,
#  'F': 12,
#  'G': 13,
#  'H': 14,
#  'I': 15,
#  'J': 16,
#  'K': 17,
#  'L': 18,
#  'M': 19,
#  'N': 20,
#  'O': 21,
#  'P': 22,
#  'Q': 23,
#  'R': 24,
#  'S': 25,
#  'T': 26,
#  'U': 27,
#  'V': 28,
#  'W': 29,
#  'X': 30,
#  'Y': 31,
#  'Z': 32,
#  '_': 33}

# %%
test_data_gen.classes
# Out:
# array([ 3,  3,  5,  7, 10, 13, 15, 17, 18, 25, 28, 35, 36, 36, 36, 36, 36,
#        36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36,
#        36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36], dtype=int32)

# %%
len(train_data_gen.classes)
# Out:
# 8

# %%
len(test_data_gen.classes)
# Out:
# 45
